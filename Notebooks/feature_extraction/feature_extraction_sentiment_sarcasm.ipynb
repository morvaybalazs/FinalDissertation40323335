# %%
#Imports
import os
import pandas as pd
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

# %%
#Global variables
data_path = '/Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/'

# %%
def extract_features_sentiment_sarcasm(dir_path, num_docs=None):
    # Get a list of file paths for all files ending with '.csv' in the given directory path
    topics_files_path = [os.path.join(dir_path, filename) for filename in os.listdir(dir_path) if filename.endswith('.csv')]

    # If num_docs argument is provided, limit the list to the first 'num_docs' files
    if num_docs is not None:
        topics_files_path = topics_files_path[:num_docs]

    # Initialize sentiment analyzer
    sentiment_analyzer = SentimentIntensityAnalyzer()

    # Initialize sarcasm detection pipeline
    sarcasm_model_name = "distilbert-base-uncased-finetuned-sst-2-english"
    sarcasm_tokenizer = AutoTokenizer.from_pretrained(sarcasm_model_name)
    sarcasm_model = AutoModelForSequenceClassification.from_pretrained(sarcasm_model_name)
    sarcasm_detector = pipeline("text-classification", model=sarcasm_model, tokenizer=sarcasm_tokenizer)

    def is_sarcastic(text):
        truncated_text = text[:512]  # Truncate the text to the first 512 tokens
        result = sarcasm_detector(truncated_text)
        if result[0]['label'] == "NEGATIVE":
            return 1
        else:
            return 0

    # Loop through each file path in the list
    for topic_file_path in topics_files_path:
        print(f"Processing {topic_file_path}")

        # Get the file name without the extension
        file_name = os.path.splitext(os.path.basename(topic_file_path))[0]
        print(f"Topic: {file_name}")

        # Read the contents of the file into a pandas dataframe
        baseline_ret_res = pd.read_csv(topic_file_path, header=0, sep='\t')

        # Print the number of rows (premises) in the dataframe
        print(f"Number of premises in file: {baseline_ret_res.shape[0]}")

        # If there are premises in the dataframe, extract features for them
        if baseline_ret_res.shape[0] > 0:
            print("Extracting sentiment and sarcasm features...")
            premises = baseline_ret_res.premises_texts
            conclusions = baseline_ret_res.conclusion
            
            # Sentiment features
            compound_premises = []
            compound_conclusions = []
            
            for premise in premises:
                if isinstance(premise, str):
                    compound_premises.append(sentiment_analyzer.polarity_scores(premise)['compound'])
                else:
                    compound_premises.append(0)

            for conclusion in conclusions:
                if isinstance(conclusion, str):
                    compound_conclusions.append(sentiment_analyzer.polarity_scores(conclusion)['compound'])
                else:
                    compound_conclusions.append(0)

            # Sarcasm features
            sarcasm_premises = [is_sarcastic(premise) if isinstance(premise, str) else 0 for premise in premises]
            sarcasm_conclusions = [is_sarcastic(conclusion) if isinstance(conclusion, str) else 0 for conclusion in conclusions]

            # Compiling extracted features for the current topic.
            print("Compiling extracted features for the current topic...")
            argument_ids = list(baseline_ret_res['docno'])
            topic_features_dict = {'qid': file_name,
                                   'docno': argument_ids,
                                   'compound_premises': compound_premises,
                                   'compound_conclusions': compound_conclusions,
                                   'sarcasm_premises': sarcasm_premises,
                                   'sarcasm_conclusions': sarcasm_conclusions}

            # Saving extracted features for the current topic to a file
            features_df = pd.DataFrame.from_dict(topic_features_dict)
            features_file_path = os.path.join(data_path + 'Data/features_extracted_2020/sentiment_sarcasm_features', f"{file_name}_features.csv")
            features_df.to_csv(features_file_path, sep=',', index=False)

            print(f"Feature extraction completed for {file_name}!")

    print("All feature extractions completed!")

# %%
#Path 2020
args_20_dir_path = data_path + "Data/arguments_2020"

#Path 2021
args_21_dir_path = data_path + "Data/arguments_2021"

#Call feature extraction 2020
extract_features_sentiment_sarcasm(args_20_dir_path)

#Call feature extraction 2021
#extract_features_sentiment_sarcasm(args_21_dir_path)
# Out:
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/6.csv
# Topic: 6
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 6!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/40.csv
# Topic: 40
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 40!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/41.csv
# Topic: 41
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 41!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/7.csv
# Topic: 7
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 7!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/43.csv
# Topic: 43
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 43!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/5.csv
# Topic: 5
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 5!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/4.csv
# Topic: 4
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 4!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/42.csv
# Topic: 42
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 42!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/46.csv
# Topic: 46
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 46!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/1.csv
# Topic: 1
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 1!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/47.csv
# Topic: 47
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 47!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/3.csv
# Topic: 3
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 3!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/45.csv
# Topic: 45
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 45!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/44.csv
# Topic: 44
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 44!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/50.csv
# Topic: 50
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 50!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/2.csv
# Topic: 2
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 2!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/37.csv
# Topic: 37
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 37!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/23.csv
# Topic: 23
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 23!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/22.csv
# Topic: 22
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 22!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/36.csv
# Topic: 36
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 36!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/20.csv
# Topic: 20
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 20!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/34.csv
# Topic: 34
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 34!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/35.csv
# Topic: 35
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 35!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/21.csv
# Topic: 21
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 21!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/31.csv
# Topic: 31
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 31!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/19.csv
# Topic: 19
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 19!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/18.csv
# Topic: 18
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 18!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/30.csv
# Topic: 30
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 30!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/24.csv
# Topic: 24
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 24!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/32.csv
# Topic: 32
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 32!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/26.csv
# Topic: 26
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 26!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/27.csv
# Topic: 27
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 27!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/33.csv
# Topic: 33
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 33!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/16.csv
# Topic: 16
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 16!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/17.csv
# Topic: 17
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 17!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/29.csv
# Topic: 29
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 29!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/15.csv
# Topic: 15
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 15!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/14.csv
# Topic: 14
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 14!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/28.csv
# Topic: 28
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 28!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/10.csv
# Topic: 10
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 10!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/38.csv
# Topic: 38
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 38!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/39.csv
# Topic: 39
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 39!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/11.csv
# Topic: 11
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 11!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/13.csv
# Topic: 13
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 13!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/12.csv
# Topic: 12
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 12!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/49.csv
# Topic: 49
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 49!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/48.csv
# Topic: 48
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 48!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/9.csv
# Topic: 9
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 9!
# Processing /Users/balazs/Desktop/dissertationProjectCode/dissertationCodeBase/Data/arguments_2020/8.csv
# Topic: 8
# Number of premises in file: 1000
# Extracting sentiment and sarcasm features...
# Compiling extracted features for the current topic...
# Feature extraction completed for 8!
# All feature extractions completed!
